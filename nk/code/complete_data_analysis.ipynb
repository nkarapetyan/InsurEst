# %%
import csv
import ast # for converting string representation into dictionary
import sys
from math import log
import numpy as np
from array import array
import pandas as pd
import math
import matplotlib.pyplot as plt

policy_ID = 'PolicyNo' # name of the first column for identifying the policies

data_dir = '../../data/'
complete_raw_train_data_file = 'training_data_2016.csv'
col_types_file = "col_types.csv"

# %%
raw_train_data_frame = pd.read_csv(data_dir + complete_raw_train_data_file) # reading complete data
#train_data_frame
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (6,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#print raw_train_data_frame.shape
#col_types_series = raw_train_data_frame.dtypes
for col in raw_train_data_frame:
    print str(col) + "  <->  " + str(raw_train_data_frame[col].dtype)
#print raw_train_data_frame
# Out:
# (424431, 69)
# PolicyNo  <->  int64
# Policy_Company  <->  object
# Policy_Installment_Term  <->  int64
# Policy_Billing_Code  <->  object
# Policy_Method_Of_Payment  <->  object
# Policy_Reinstatement_Fee_Indicator  <->  object
# Policy_Zip_Code_Garaging_Location  <->  object
# Vehicle_Territory  <->  int64
# Vehicle_Make_Year  <->  int64
# Vehicle_Make_Description  <->  object
# Vehicle_Performance  <->  object
# Vehicle_New_Cost_Amount  <->  int64
# Vehicle_Symbol  <->  int64
# Vehicle_Number_Of_Drivers_Assigned  <->  int64
# Vehicle_Usage  <->  object
# Vehicle_Miles_To_Work  <->  int64
# Vehicle_Days_Per_Week_Driven  <->  int64
# Vehicle_Annual_Miles  <->  object
# Vehicle_Anti_Theft_Device  <->  object
# Vehicle_Passive_Restraint  <->  object
# Vehicle_Age_In_Years  <->  int64
# Vehicle_Med_Pay_Limit  <->  int64
# Vehicle_Bodily_Injury_Limit  <->  object
# Vehicle_Physical_Damage_Limit  <->  int64
# Vehicle_Comprehensive_Coverage_Indicator  <->  object
# ...

# %% [markdown]
# ##### -1. writing the series with column type information for filling them later by hand
# #### -1.0. uncomment it if want to rewrite the file

# %%
#f = open(data_dir + col_types_file, 'wt')
#types_header = ('Attribute Name', 'Type')
#col_types_series.to_csv(path = data_dir + col_types_file ,header = True,index_label = types_header)

# %% [markdown]
# ##### -1.1. Reading the dictionry and column type informations into dataframe

# %%
col_types = pd.read_csv(data_dir + col_types_file)
col_types
col_types_heading = col_types.columns.values
col_types_heading
raw_train_data_frame.shape
# Out:
# (424422, 69)

# %%
#raw_train_data_frame = raw_train_data_frame.drop(policy_ID, 1)
#for col_name in cols:
#    if (raw_train_data_frame[col_name].dtype == 'object'):
#        raw_train_data_frame = raw_train_data_frame.drop(col_name, 1)
#cols = raw_train_data_frame.columns.values
#cols
#raw_train_data_frame.shape

# %% [markdown]
# ## 0. Analysis
# ### 0.1. writing into the file the frequency information of all columns except Policy ID

# %%
## THIS PART SCALES FEATURES IN RANGE OF 0 to 1
#from sklearn import preprocessing

df = raw_train_data_frame

#print df.shape

#scaler = preprocessing.MinMaxScaler()
#df_scaled = preprocessing.robust_scale(df)

#df_scaled = pd.DataFrame(df_scaled, columns=df.columns.values)
#df_scaled = pd.DataFrame(scaler.fit_transform(df_scaled), columns=df.columns.values)

#print df_scaled
#print df_scaled.shape

# %%
for col_name in cols:
    if (col_name == policy_ID or df[col_name].dtype == 'object'):
        continue
    from sklearn import preprocessing

    scaler = preprocessing.MinMaxScaler()
    df_scaled = pd.DataFrame(df_scaled, columns=df.columns.values)
    df_scaled = pd.DataFrame(scaler.fit_transform(df_scaled), columns=df.columns.values)

print df
print df.shape
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/preprocessing/data.py:986: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /usr/local/lib/python2.7/dist-packages/sklearn/preprocessing/data.py:1008: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# ...

# %%
for col_name in cols:
    if (col_name == policy_ID or df[col_name].dtype == 'object'):
        continue
    frq = df.groupby(col_name)
    ## uncomment following codes to redirect frequncy information from std.out into the file
    #pd.set_option('display.max_rows', len(frq.size())) ## this forces panda to print series fully
    #sys.stdout = open(col_name + "__frequency.txt", 'w') # this redirect stdout to the file
    print frq.size()
    #print "--------------------------------------------------------------"

# %% [markdown]
# ### 0.2. Statistical information on the columns

# %%
#pd.set_option('display.max_columns', len(df.columns))
#el = df.describe()
#outFile = 'columns_statistics.csv'
#el.to_csv(path_or_buf = data_dir + outFile)

# %% [markdown]
# ## 1. Data Cleaning portion
# ### 1.0. Remove the dublicates at first

# %%
import copy
#df = copy.deepcopy(raw_train_data_frame) # we will perform cleaning operations on the df dataframe
df = raw_train_data_frame
#df = df.drop(policy_ID, 1) # will drop the policyID column from the dataframe
cols = list(df.columns.values) # the argument return the header
#print cols
#df.shape
cols.remove(policy_ID)
#print cols
rem_dup=df.drop_duplicates(cols)

print len(rem_dup)
print len(df)
df = rem_dup
# Out:
# 424422
# 424431

# %% [markdown]
# ### 1.1. By Column cleaning
# #### 1.1.0. Define a generic function using Pandas replace function

# %%
def coding(col, codeDict):
    colCoded = pd.Series(col, copy=True)
    for key, value in codeDict.items():
        colCoded.replace(key, value, inplace=True)
    return colCoded

# %% [markdown]
# #### 1.1.1. ALL columns that Have toBinary or toNumerical values will be coded according to their dictionary code recorded in the cols_type information
# #### **The following is a helper methods for accessing row data

# %%
#index 0  is 'attribute name', 1 is the 'type'
#for row in col_types.iterrows():
#   print row[1]['Attribute Name']    #Example how to access row in dataframe and it's elements by the name of column
#   break

# %%
attr_name = 'Attribute Name'
attr_type = 'Type'
attr_dict = 'code_dictionary'
i = 0
        
for row in col_types.iterrows():
    if(row[1][attr_type] == 'toBinary' or row[1][attr_type] == 'toNumerical'):
        col_name = row[1][attr_name]
        col_dict = ast.literal_eval(row[1][attr_dict])
        #DEBUG
        #print col_dict
        
        pd_before = pd.value_counts(df[col_name])
        #DEBUG
        df[col_name] = coding(df[col_name], col_dict)
        #DEBUG
        if(df[col_name].dtype == 'object'):
            i+=1
            print 'Before Coding:'
            print pd_before
            print 'After Coding:'
            print pd.value_counts(df[col_name])
        #DEBUG
        
        #print row
print i
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0

# %%
outFile = 'traning_cleaned_nk.csv'
df.to_csv(path_or_buf = data_dir + outFile, index=False)
df.shape
# Out:
# (424422, 69)
